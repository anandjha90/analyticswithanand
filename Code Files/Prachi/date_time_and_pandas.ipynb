# %%
import pandas as pd

# %%
sales = pd.DataFrame({'Region':['E','E','W','W'],'Amount':[100,80,120,60]})

# %%
sales
# Out:
#   Region  Amount
# 0      E     100
# 1      E      80
# 2      W     120
# 3      W      60

# %%
select Region,SUM(Amount) FROM sales group by Region

# %%
out = sales.groupby('Region').agg(total=('Amount','sum'),avg=('Amount','mean'))

# %%
out
# Out:
#         total   avg
# Region
# E         180  90.0
# W         180  90.0

# %%
pd.pivot_table(sales,values='Amount',index='Region',columns = None,aggfunc='sum',fill_value = 0)
# Out:
#         Amount
# Region
# E          180
# W          180

# %%
users = pd.DataFrame({'id':[1,2],'name':['Shalinee','Bindu']})
salary = pd.DataFrame({'id':[1,2,3],'salary':[10000,20000,40000]})

# %%
merged = users.merge(salary,on ='id',how='right')

# %%
merged
# Out:
#    id      name  salary
# 0   1  Shalinee   10000
# 1   2     Bindu   20000
# 2   3       NaN   40000

# %%
select users.id,users.name ,salary.salary from users left join salary on users.id=salary.id

# %%
north = pd.DataFrame({'city':['NY'],'sales':[120]})
south = pd.DataFrame({'city':['LA'],'sales':[100]})

# %%
north
# Out:
#   city  sales
# 0   NY    120

# %%
south
# Out:
#   city  sales
# 0   LA    100

# %%
rows = pd.concat([north,south],axis=0,ignore_index=True)

# %%
rows
# Out:
#   city  sales
# 0   NY    120
# 1   LA    100

# %%
rows = pd.concat([north,south],axis=1,ignore_index=True)

# %%
rows
# Out:
#     0    1   2    3
# 0  NY  120  LA  100

# %%
rows = pd.concat([north[['city']],south[['city']]],axis=0,ignore_index=True)

# %%
rows
# Out:
#   city
# 0   NY
# 1   LA

# %%
cust = pd.Series(['alice','BOB','Charliee'])

# %%
clean_df= cust.str.strip().str.title()

# %%
clean_df
# Out:
# 0       Alice
# 1         Bob
# 2    Charliee
# dtype: object

# %%
mask=clean_df.str.contains('Bo',case=False)

# %%
mask
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
cust = pd.Series(['alice','BOB','Charliee'])

# %%
mask=clean_df.str.contains('ice',case=True)

# %%
mask
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
df = pd.DataFrame({"full_name":['Alice johnson','Bob smith','charliee Lee'],"age":[24,30,28]})

# %%
df['age_sq'] = df['age'].apply(lambda x:x*x)

# %%
df
# Out:
#        full_name  age  age_sq
# 0  Alice johnson   24     576
# 1      Bob smith   30     900
# 2   charliee Lee   28     784

# %%
df['full_name'] = df['full_name'].apply(lambda x: x.upper())

# %%
df
# Out:
#        full_name  age  age_sq
# 0  ALICE JOHNSON   24     576
# 1      BOB SMITH   30     900
# 2   CHARLIEE LEE   28     784

# %%
upper = df[["full_name"]].applymap(lambda x: x.upper())
# Out:
# C:\Users\prach\AppData\Local\Temp\ipykernel_15844\248877468.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   upper = df[["full_name"]].applymap(lambda x: x.upper())

# %%
df
# Out:
#        full_name  age  age_sq
# 0  ALICE JOHNSON   24     576
# 1      BOB SMITH   30     900
# 2   CHARLIEE LEE   28     784

# %%
upper
# Out:
#        full_name
# 0  ALICE JOHNSON
# 1      BOB SMITH
# 2   CHARLIEE LEE

# %%
df.rename(columns={"full_name": "FULL_NAME"}, inplace=True)

# %%
df
# Out:
#        FULL_NAME  age  age_sq
# 0  ALICE JOHNSON   24     576
# 1      BOB SMITH   30     900
# 2   CHARLIEE LEE   28     784

# %%
ts = pd.Series([10,20,30,40,50])

# %%
rolling_sum=ts.cumsum()

# %%
rolling_sum
# Out:
# 0     10
# 1     30
# 2     60
# 3    100
# 4    150
# dtype: int64

# %%
roll_avg = ts.rolling(2).mean()

# %%
roll_avg
# Out:
# 0     NaN
# 1    15.0
# 2    25.0
# 3    35.0
# 4    45.0
# dtype: float64

# %%
shift_test = ts.shift(2)

# %%
shift_test
# Out:
# 0     NaN
# 1     NaN
# 2    10.0
# 3    20.0
# 4    30.0
# dtype: float64

# %%
import pandas as pd

dates = pd.date_range("2025-01-01", periods=10, freq="D")
sales = [20,22,19,30,25,27,35,40,38,45]

# %%
df = pd.DataFrame({"date":dates,'sales':sales})

# %%
df
# Out:
#         date  sales
# 0 2025-01-01     20
# 1 2025-01-02     22
# 2 2025-01-03     19
# 3 2025-01-04     30
# 4 2025-01-05     25
# 5 2025-01-06     27
# 6 2025-01-07     35
# 7 2025-01-08     40
# 8 2025-01-09     38
# 9 2025-01-10     45

# %%
df['rolling_mean_3d'] = df['sales'].rolling(window=3).mean()

# %%
df
# Out:
#         date  sales  rolling_mean_3d
# 0 2025-01-01     20              NaN
# 1 2025-01-02     22              NaN
# 2 2025-01-03     19        20.333333
# 3 2025-01-04     30        23.666667
# 4 2025-01-05     25        24.666667
# 5 2025-01-06     27        27.333333
# 6 2025-01-07     35        29.000000
# 7 2025-01-08     40        34.000000
# 8 2025-01-09     38        37.666667
# 9 2025-01-10     45        41.000000

# %%
df['rolling_sum_3d'] = df['sales'].rolling(window=3).sum()

# %%
df
# Out:
#         date  sales  rolling_mean_3d  rolling_sum_3d
# 0 2025-01-01     20              NaN             NaN
# 1 2025-01-02     22              NaN             NaN
# 2 2025-01-03     19        20.333333            61.0
# 3 2025-01-04     30        23.666667            71.0
# 4 2025-01-05     25        24.666667            74.0
# 5 2025-01-06     27        27.333333            82.0
# 6 2025-01-07     35        29.000000            87.0
# 7 2025-01-08     40        34.000000           102.0
# 8 2025-01-09     38        37.666667           113.0
# 9 2025-01-10     45        41.000000           123.0

# %%
df['rolling_max_3d'] = df['sales'].rolling(window=3).max()

# %%
df
# Out:
#         date  sales  rolling_mean_3d  rolling_sum_3d  rolling_max_3d
# 0 2025-01-01     20              NaN             NaN             NaN
# 1 2025-01-02     22              NaN             NaN             NaN
# 2 2025-01-03     19        20.333333            61.0            22.0
# 3 2025-01-04     30        23.666667            71.0            30.0
# 4 2025-01-05     25        24.666667            74.0            30.0
# 5 2025-01-06     27        27.333333            82.0            30.0
# 6 2025-01-07     35        29.000000            87.0            35.0
# 7 2025-01-08     40        34.000000           102.0            40.0
# 8 2025-01-09     38        37.666667           113.0            40.0
# 9 2025-01-10     45        41.000000           123.0            45.0

# %%
df2 = pd.DataFrame({"store":["A"]*5 +["B"]*5,
                    "day":range(1,11),
                    "sales":[10,20,25,25,30,35,40,55,67,89]})

# %%
df2
# Out:
#   store  day  sales
# 0     A    1     10
# 1     A    2     20
# 2     A    3     25
# 3     A    4     25
# 4     A    5     30
# 5     B    6     35
# 6     B    7     40
# 7     B    8     55
# 8     B    9     67
# 9     B   10     89

# %%
df2['rolling_mean_perstore']=df2.groupby('store')['sales'].transform(lambda x:x.rolling(2).mean())

# %%
df2
# Out:
#   store  day  sales  rolling_mean_perstore
# 0     A    1     10                    NaN
# 1     A    2     20                   15.0
# 2     A    3     25                   22.5
# 3     A    4     25                   25.0
# 4     A    5     30                   27.5
# 5     B    6     35                    NaN
# 6     B    7     40                   37.5
# 7     B    8     55                   47.5
# 8     B    9     67                   61.0
# 9     B   10     89                   78.0

# %%
Compute a 7-day rolling average of sales and compare with expanding average.

Find the rolling standard deviation (5 days) for a stock price dataset.

Use EWM to smooth noisy daily temperature data.

For each store, calculate the 3-day rolling sum of sales.

# %%
df
# Out:
#         date  sales  rolling_mean_3d  rolling_sum_3d  rolling_max_3d
# 0 2025-01-01     20              NaN             NaN             NaN
# 1 2025-01-02     22              NaN             NaN             NaN
# 2 2025-01-03     19        20.333333            61.0            22.0
# 3 2025-01-04     30        23.666667            71.0            30.0
# 4 2025-01-05     25        24.666667            74.0            30.0
# 5 2025-01-06     27        27.333333            82.0            30.0
# 6 2025-01-07     35        29.000000            87.0            35.0
# 7 2025-01-08     40        34.000000           102.0            40.0
# 8 2025-01-09     38        37.666667           113.0            40.0
# 9 2025-01-10     45        41.000000           123.0            45.0

# %%
df["expanding_mean"] = df["sales"].expanding().mean()

# %%
df
# Out:
#         date  sales  rolling_mean_3d  rolling_sum_3d  rolling_max_3d  \
# 0 2025-01-01     20              NaN             NaN             NaN
# 1 2025-01-02     22              NaN             NaN             NaN
# 2 2025-01-03     19        20.333333            61.0            22.0
# 3 2025-01-04     30        23.666667            71.0            30.0
# 4 2025-01-05     25        24.666667            74.0            30.0
# 5 2025-01-06     27        27.333333            82.0            30.0
# 6 2025-01-07     35        29.000000            87.0            35.0
# 7 2025-01-08     40        34.000000           102.0            40.0
# 8 2025-01-09     38        37.666667           113.0            40.0
# 9 2025-01-10     45        41.000000           123.0            45.0
#
#    expanding_mean
# 0       20.000000
# 1       21.000000
# 2       20.333333
# 3       22.750000
# 4       23.200000
# 5       23.833333
# 6       25.428571
# 7       27.250000
# 8       28.444444
# ...

# %%
dates = pd.date_range("2025-01-01", periods=10, freq="MS")

# %%
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#                '2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01',
#                '2025-09-01', '2025-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
dates = pd.date_range("2025-01-01", periods=10, freq="B")

# %%
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-06',
#                '2025-01-07', '2025-01-08', '2025-01-09', '2025-01-10',
#                '2025-01-13', '2025-01-14'],
#               dtype='datetime64[ns]', freq='B')

# %%
dates = pd.date_range("2025-01-01", periods=10, freq="W-MON")

# %%
dates
# Out:
# DatetimeIndex(['2025-01-06', '2025-01-13', '2025-01-20', '2025-01-27',
#                '2025-02-03', '2025-02-10', '2025-02-17', '2025-02-24',
#                '2025-03-03', '2025-03-10'],
#               dtype='datetime64[ns]', freq='W-MON')

# %%
df = pd.DataFrame({'dates' : pd.date_range("2025-01-01", periods=10, freq="D")})

# %%
df
# Out:
#        dates
# 0 2025-01-01
# 1 2025-01-02
# 2 2025-01-03
# 3 2025-01-04
# 4 2025-01-05
# 5 2025-01-06
# 6 2025-01-07
# 7 2025-01-08
# 8 2025-01-09
# 9 2025-01-10

# %%
df["year"] = df["dates"].dt.year

# %%
df
# Out:
#        dates  year
# 0 2025-01-01  2025
# 1 2025-01-02  2025
# 2 2025-01-03  2025
# 3 2025-01-04  2025
# 4 2025-01-05  2025
# 5 2025-01-06  2025
# 6 2025-01-07  2025
# 7 2025-01-08  2025
# 8 2025-01-09  2025
# 9 2025-01-10  2025

# %%
df["month"] = df["dates"].dt.month

# %%
df
# Out:
#        dates  year  month
# 0 2025-01-01  2025      1
# 1 2025-01-02  2025      1
# 2 2025-01-03  2025      1
# 3 2025-01-04  2025      1
# 4 2025-01-05  2025      1
# 5 2025-01-06  2025      1
# 6 2025-01-07  2025      1
# 7 2025-01-08  2025      1
# 8 2025-01-09  2025      1
# 9 2025-01-10  2025      1

# %%
df["day"] = df["dates"].dt.day

# %%
df
# Out:
#        dates  year  month  day
# 0 2025-01-01  2025      1    1
# 1 2025-01-02  2025      1    2
# 2 2025-01-03  2025      1    3
# 3 2025-01-04  2025      1    4
# 4 2025-01-05  2025      1    5
# 5 2025-01-06  2025      1    6
# 6 2025-01-07  2025      1    7
# 7 2025-01-08  2025      1    8
# 8 2025-01-09  2025      1    9
# 9 2025-01-10  2025      1   10

# %%
df["weekday"] = df["dates"].dt.day_name()

# %%
df
# Out:
#        dates  year  month  day    weekday
# 0 2025-01-01  2025      1    1  Wednesday
# 1 2025-01-02  2025      1    2   Thursday
# 2 2025-01-03  2025      1    3     Friday
# 3 2025-01-04  2025      1    4   Saturday
# 4 2025-01-05  2025      1    5     Sunday
# 5 2025-01-06  2025      1    6     Monday
# 6 2025-01-07  2025      1    7    Tuesday
# 7 2025-01-08  2025      1    8  Wednesday
# 8 2025-01-09  2025      1    9   Thursday
# 9 2025-01-10  2025      1   10     Friday

# %%
df["week"] = df["dates"].dt.isocalendar().week

# %%
df
# Out:
#        dates  year  month  day    weekday  week
# 0 2025-01-01  2025      1    1  Wednesday     1
# 1 2025-01-02  2025      1    2   Thursday     1
# 2 2025-01-03  2025      1    3     Friday     1
# 3 2025-01-04  2025      1    4   Saturday     1
# 4 2025-01-05  2025      1    5     Sunday     1
# 5 2025-01-06  2025      1    6     Monday     2
# 6 2025-01-07  2025      1    7    Tuesday     2
# 7 2025-01-08  2025      1    8  Wednesday     2
# 8 2025-01-09  2025      1    9   Thursday     2
# 9 2025-01-10  2025      1   10     Friday     2

# %%
df["quarter"] = df["dates"].dt.quarter

# %%
df
# Out:
#        dates  year  month  day    weekday  week  quarter
# 0 2025-01-01  2025      1    1  Wednesday     1        1
# 1 2025-01-02  2025      1    2   Thursday     1        1
# 2 2025-01-03  2025      1    3     Friday     1        1
# 3 2025-01-04  2025      1    4   Saturday     1        1
# 4 2025-01-05  2025      1    5     Sunday     1        1
# 5 2025-01-06  2025      1    6     Monday     2        1
# 6 2025-01-07  2025      1    7    Tuesday     2        1
# 7 2025-01-08  2025      1    8  Wednesday     2        1
# 8 2025-01-09  2025      1    9   Thursday     2        1
# 9 2025-01-10  2025      1   10     Friday     2        1

# %%
from datetime import timedelta

# %%
df["date_plus_7"] = df["dates"] + pd.Timedelta(days=7)

# %%
df
# Out:
#        dates  year  month  day    weekday  week  quarter date_plus_7
# 0 2025-01-01  2025      1    1  Wednesday     1        1  2025-01-08
# 1 2025-01-02  2025      1    2   Thursday     1        1  2025-01-09
# 2 2025-01-03  2025      1    3     Friday     1        1  2025-01-10
# 3 2025-01-04  2025      1    4   Saturday     1        1  2025-01-11
# 4 2025-01-05  2025      1    5     Sunday     1        1  2025-01-12
# 5 2025-01-06  2025      1    6     Monday     2        1  2025-01-13
# 6 2025-01-07  2025      1    7    Tuesday     2        1  2025-01-14
# 7 2025-01-08  2025      1    8  Wednesday     2        1  2025-01-15
# 8 2025-01-09  2025      1    9   Thursday     2        1  2025-01-16
# 9 2025-01-10  2025      1   10     Friday     2        1  2025-01-17

# %%
df["date_plus_1M"] = df["dates"] + pd.DateOffset(months=1)

# %%
df
# Out:
#        dates  year  month  day    weekday  week  quarter date_plus_7  \
# 0 2025-01-01  2025      1    1  Wednesday     1        1  2025-01-08
# 1 2025-01-02  2025      1    2   Thursday     1        1  2025-01-09
# 2 2025-01-03  2025      1    3     Friday     1        1  2025-01-10
# 3 2025-01-04  2025      1    4   Saturday     1        1  2025-01-11
# 4 2025-01-05  2025      1    5     Sunday     1        1  2025-01-12
# 5 2025-01-06  2025      1    6     Monday     2        1  2025-01-13
# 6 2025-01-07  2025      1    7    Tuesday     2        1  2025-01-14
# 7 2025-01-08  2025      1    8  Wednesday     2        1  2025-01-15
# 8 2025-01-09  2025      1    9   Thursday     2        1  2025-01-16
# 9 2025-01-10  2025      1   10     Friday     2        1  2025-01-17
#
#   date_plus_1M
# 0   2025-02-01
# 1   2025-02-02
# 2   2025-02-03
# 3   2025-02-04
# 4   2025-02-05
# 5   2025-02-06
# 6   2025-02-07
# 7   2025-02-08
# 8   2025-02-09
# 9   2025-02-10

# %%
df["date_plus_1Y"] = df["dates"] + pd.DateOffset(years=1)

# %%
df
# Out:
#        dates  year  month  day    weekday  week  quarter date_plus_7  \
# 0 2025-01-01  2025      1    1  Wednesday     1        1  2025-01-08
# 1 2025-01-02  2025      1    2   Thursday     1        1  2025-01-09
# 2 2025-01-03  2025      1    3     Friday     1        1  2025-01-10
# 3 2025-01-04  2025      1    4   Saturday     1        1  2025-01-11
# 4 2025-01-05  2025      1    5     Sunday     1        1  2025-01-12
# 5 2025-01-06  2025      1    6     Monday     2        1  2025-01-13
# 6 2025-01-07  2025      1    7    Tuesday     2        1  2025-01-14
# 7 2025-01-08  2025      1    8  Wednesday     2        1  2025-01-15
# 8 2025-01-09  2025      1    9   Thursday     2        1  2025-01-16
# 9 2025-01-10  2025      1   10     Friday     2        1  2025-01-17
#
#   date_plus_1M date_plus_1Y
# 0   2025-02-01   2026-01-01
# 1   2025-02-02   2026-01-02
# 2   2025-02-03   2026-01-03
# 3   2025-02-04   2026-01-04
# 4   2025-02-05   2026-01-05
# 5   2025-02-06   2026-01-06
# ...

# %%
df["days_diff"] = (df["date
