# %%
import logging

# Configure basic logging
logging.basicConfig(level=logging.ERROR)

# Log messages of various levels
logging.debug("debug message.")
logging.info("user logged in.")
logging.warning("warning message")
logging.error("This is an error message.")
logging.critical("This is a critical message.")
# Out:
# ERROR:root:This is an error message.
# CRITICAL:root:This is a critical message.

# %%
import logging

logging.basicConfig(filename="app.log",
                    format="%(name)s - %(asctime)s - %(levelname)s - %(message)s",
                    datefmt="%Y-%m-%d %H:%M:%S",
                    level=logging.INFO)

logging.info("user logged in")
# Out:
# 2025-07-12 13:50:08 |INFO - user logged in

# %%
import os
with open('app.log') as file:
    content = file.read()
    print(content)
# Out:
# 2025-07-12 13:39:20 - INFO - user logged in
# 2025-07-12 13:58:28,003 - INFO - Another log line
# 2025-07-12 14:09:50,493 - INFO - Entered number is 10 and 5
# 2025-07-12 14:09:50,493 - INFO - Performing basic operations
# 2025-07-12 14:11:02,469 - INFO - Entered number is 10 and 0
# 2025-07-12 14:11:02,469 - INFO - Performing basic operations
# 2025-07-12 14:11:02,470 - ERROR - Not Divisible by Zero

# %%
import logging

logging.basicConfig(
                    format="%(levelno)s - %(asctime)s |%(levelname)s - %(message)s",
                    datefmt="%Y-%m-%d %H:%M:%S",
                    level=logging.INFO)

logging.info("user logged in")
# Out:
# 20 - 2025-07-12 13:52:00 |INFO - user logged in

# %%
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logging.info("Another log line")

# %%
'''
take input from user 
basic calculator 
0div error handle it 
print the level using logging
'''
import logging
logging.basicConfig(
    filename="app.log", # we can remove it to display directly 
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.INFO
)
Number1 = int(input("Enter first numbers: \n"))
Number2 = int(input("Enter Second number :\n"))
logging.info(f"Entered number is {Number1} and {Number2}")
logging.info("Performing basic operations ")

Addition = Number1 + Number2
subtraction = Number1 - Number2
try:
    dividion = Number1 / Number2
except ZeroDivisionError:
    logging.error("Not Divisible by Zero")
# Out:
# Enter first numbers:
#  10
# Enter Second number :
#  0

# %%
import logging
logging.basicConfig(
level=logging.INFO,
format="%(asctime)s | %(levelname)-s | %(name)s | %(message)s",
handlers=[
logging.FileHandler("app1.log", encoding="utf‑8"),
logging.StreamHandler() # defaults to stderr
]
)


logging.info("test mesage")
# Out:
# 2025-07-12 14:19:50,583 | INFO | root | test mesage

# %%
import logging
logging.basicConfig(
level=logging.INFO,
format="%(asctime)s | %(levelname)-s | %(name)s | %(message)s",
handlers=[
logging.FileHandler("app1.log", encoding="utf‑8"),
logging.StreamHandler() # defaults to stderr
]
)


logging.info("test mesage")
# Out:
# 2025-07-12 14:21:15,883 | INFO | root | test mesage
