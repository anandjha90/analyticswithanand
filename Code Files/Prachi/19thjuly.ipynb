# %%
def square(x):
    return x**2

# %%
square(5)
# Out:
# 25

# %%
square=lambda x: x**2

# %%
square(4)
# Out:
# 16

# %%
calc = lambda  x,y: (x+y)*(x-y)

# %%
calc(5,2)
# Out:
# 21

# %%
max_value = lambda a,b: a if a>b else b

# %%
max_value(9,7)
# Out:
# 9

# %%
chain_ex = lambda x: (x**2,x**3,x+5)

# %%
chain_ex(2)
# Out:
# (4, 8, 7)

# %%
apply_dis = lambda price: price*0.9

# %%
items = [100,200,400,600,1000]

discounted_pp=list(map(apply_dis,items))

# %%
discounted_pp
# Out:
# [90.0, 180.0, 360.0, 540.0, 900.0]

# %%
x+=3


add = lambda x: x=x+3
# Out:
#   Cell In[17], line 4
#     add = lambda x: x=x+3
#           ^
# SyntaxError: cannot assign to lambda

# %%
people = [("Alice", 30), ("Bob", 25), ("Charlie", 35)]


get_age = lambda person: person[1]


sorted_people = sorted(people,key=get_age)

# %%
sorted_people
# Out:
# [('Bob', 25), ('Alice', 30), ('Charlie', 35)]

# %%
get_age(("Bob", 25))
# Out:
# 'Bob'

# %%
def square(x):
    return x**2

# %%
square(4)
# Out:
# 16

# %%
l = [3,7,4,5,10]

# %%
mapped_list = list(map(square,l))

# %%
print(mapped_list)
# Out:
# [9, 49, 16, 25, 100]

# %%
for i in range(5):
    print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
nums = [1, 2, 3, 4]
sq=[x*x for x in nums]
print(sq)
# Out:
# [1, 4, 9, 16]

# %%
list = [3, 7, 4, 5, 10]
ls = []
for x in list:
    ls.append(x*x)

# %%
ls
# Out:
# [9, 49, 16, 25, 100]

# %%
list = [3, 7, 4, 5, 10]
def sq(lst):
    ls = []
    for x in list:
        ls.append(x*x)
    return ls

sq(list)
# Out:
# [9, 49, 16, 25, 100]

# %%
items = [100,200,400,600,1000]

# %%
pr = [100, 200, 300, 400]
di= list(map(lambda x: x * 0.9, pr))
print(di)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 pr = [100, 200, 300, 400]
# ----> 2 di= list(map(lambda x: x * 0.9, pr))
#       3 print(di)
#
# TypeError: 'list' object is not callable

# %%
items=[100,200,300,400,500]

discounted_price=list(map(lambda x:x*0.5,items))
print(discounted_price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 items=[100,200,300,400,500]
# ----> 3 discounted_price=list(map(lambda x:x*0.5,items))
#       4 print(discounted_price)
#
# TypeError: 'list' object is not callable

# %%
items = [100, 200, 300, 400, 500]

discounted_price = list(map(lambda x: x * 0.5, items))
print(discounted_price)
# Out:
# [50.0, 100.0, 150.0, 200.0, 250.0]

# %%
def odd_num(x):
    return x%2 !=0

# %%
odd_num(23)
# Out:
# True

# %%
numbers=[23,45,68,70,109,102,304,607]

# %%
filtered_list = list(filter(odd_num,numbers))

# %%
filtered_list
# Out:
# [23, 45, 109, 607]

# %%
filtered_list_lambda = list(filter(lambda x: x%2!=0,numbers))

# %%
filtered_list_lambda
# Out:
# [23, 45, 109, 607]

# %%
new_mapped_list=list(map(odd_num,numbers))

# %%
new_mapped_list
# Out:
# [True, True, False, False, True, False, False, True]

# %%
def sq(x):
    return x**2

# %%
new_mapped_list=list(map(sq,numbers))

# %%
new_mapped_list
# Out:
# [529, 2025, 4624, 4900, 11881, 10404, 92416, 368449]

# %%
#Reduce -

# %%
def sum_all(x,y):
    return x+y

# %%
numbers=[1,2,3,5]

# %%
from functools import reduce


result = reduce(sum_all,numbers)

# %%
result
# Out:
# 11

# %%
result = reduce(lambda x,y: x+y,numbers)

# %%
result
# Out:
# 11

# %%
(((1+2)+3)+5)

# %%
result = reduce(lambda x,y: x*y,numbers)

# %%
result
# Out:
# 30

# %%
words = ["Python", "is", "fantastic", "and", "fun"]

# %%
words= [ "python", "is", "fantastic", "and", "fun"]
lw = reduce(lambda x, y: x if len(x) > len(y) else y, words)

print(lw)
# Out:
# fantastic

# %%
numbers=[23,45,68,70,109,102,304,607]

# %%
from functools import reduce
words = ["python", 'is', 'fantastic', 'and', 'fun']

result = reduce(lambda x,y: x if len(x)>len(y) else y, words)
result
# Out:
# 'fantastic'

# %%
from functools import reduce
number=[23,45,68,70,109,102,304,607]
ln=reduce(lambda x,y:x if x>y else y,number)
print(ln)
# Out:
# 607

# %%
from functools import reduce
print(reduce(lambda x, y: x + str(y), ['A', 20, 'C']))
# Out:
# A20C
