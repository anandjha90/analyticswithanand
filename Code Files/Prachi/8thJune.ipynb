# %% [markdown]
# Identity Operator - is, is not

# %%
x1 = 10
y1 = 10

# %%
id(x1)
# Out:
# 140704613450824

# %%
id(y1)
# Out:
# 140704613450824

# %%
x1 is y1
# Out:
# False

# %%
x is x
# Out:
# True

# %%
x is not y
# Out:
# True

# %%
x=[1,2]
y=[1,2]

# %%
x is y
# Out:
# False

# %%
id(x)
# Out:
# 2318633575360

# %%
id(y)
# Out:
# 2318634045632

# %%
x1 = 10
x2 = 10

# %%
id(x1)
# Out:
# 140704613450824

# %%
id(x2)
# Out:
# 140704613450824

# %% [markdown]
# -5  to 256
#
# Python automatically reuses memory (i.e., the same object) for small integers to optimize performance. This is called integer interning.

# %%
x3 = 278
x4 = 278

# %%
x2 is x3
# Out:
# False

# %%
id(x3)
# Out:
# 2318633640880

# %%
id(x4)
# Out:
# 2318633638512

# %%
x=257
y=257

# %%
x is y
# Out:
# False

# %%
x3 = 10
x4 = -5

# %%
id(x3)
# Out:
# 140704613450824

# %%
id(x4)
# Out:
# 140704613450344

# %%
x3 is x4
# Out:
# False

# %%
x5 = -12
x6 = 257

# %%
x5 is x6
# Out:
# False

# %%
x7 = -5 
x8 = 257

# %%
x7 is x8
# Out:
# False

# %%
x9 = -257
x10 = 257

# %%
id(x9)
# Out:
# 2318633640688

# %%
id(x10)
# Out:
# 2318633640624

# %%
x9 is x10
# Out:
# False

# %% [markdown]
# In Operator - to test if value is in sequence or not (list,tuple,string)

# %%
fruit = 'Apple'

# %%
'l' in fruit
# Out:
# True

# %%
l = ['Aryan','Sagar','prachi','Anand']

# %%
'Prachi' in l
# Out:
# False

# %%
l=["Sagar","Pol","Prachi"]

# %%
Bitwise --> used to perform binary operations

# %%
5&3
# Out:
# 1

# %%
----> 101&11

# %%
10&7
# Out:
# 2

# %%
10|7
# Out:
# 15

# %%
~10
# Out:
# -11

# %%
~3
# Out:
# -4

# %%
~70
# Out:
# -71

# %%
Typecasting - efers to convert one data type to another

1)implicit - automatically converts the data type without any external support
2)Explicit - manuall conversion (int(),float(),bool(),str(),list(),tuple(),set())

# %%
a= 10 #10.0
b= 5.5

# %%
a+b  #int+float
# Out:
# 15.5

# %%
a= 10.5
b= 11.5

# %%
a+b
# Out:
# 22.0

# %%
a = 10
b= 20.7

# %%
a+ int(b)
# Out:
# 30

# %%
float(a)+b
# Out:
# 30.7

# %%
a+b
# Out:
# 30.7

# %%
x= 9.7
y= int(x)

# %%
y
# Out:
# 9

# %%
x = 10
y = float(x)

# %%
y
# Out:
# 10.0

# %%
type(y)
# Out:
# float

# %%
x = 100

# %%
type(x)
# Out:
# int

# %%
y = str(x)

# %%
type(y)
# Out:
# str

# %%
x = 'prachi'

# %%
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 int(x)
#
# ValueError: invalid literal for int() with base 10: 'prachi'

# %%
x = '100'

# %%
type(x)
# Out:
# str

# %%
y=int(x)

# %%
type(y)
# Out:
# int

# %%
s = "3.14"

# %%
t = float(s)

# %%
type(t)
# Out:
# float

# %%
x = 0

# %%
bool(0)
# Out:
# False

# %%
y = 1

# %%
bool(y)
# Out:
# True

# %%
z= 5

# %%
bool(z)
# Out:
# True

# %%
z1 = -9

# %%
bool(z1)
# Out:
# True

# %%
a = [1,2,3,4,5,4,7,2]

# %%
type(a)
# Out:
# list

# %%
b= set(a)

# %%
b
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
type(b)
# Out:
# set

# %%
age= "18"

# %%
if int(age)>=18:
    print("eligible for the vote")
# Out:
# eligible for the vote

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10

# %%
print("number is:",a)
# Out:
# number is: 10

# %%
a = 10
b = 7

# %%
sum = a + b
sub = a- b
mul = a*b
div = a/b

# %%
print("sum of ",a, " and",b," is",sum)
# Out:
# sum of  10  and 7  is 17

# %%
print("a","b","c",sep = ':')
# Out:
# a:b:c

# %%
print("Hello",end =" ")
print("World")
# Out:
# Hello World

# %%
print("Hello",end=" ")
print("I am",end = " ")
print("prachi")
# Out:
# Hello I am prachi

# %%
name = "Prachi"
age = 25

# %%
print(name,end=",")
print (age)
# Out:
# Prachi,25

# %%
print("name:",name)
print("age:",age)
# Out:
# name: Prachi
# age: 25

# %%
print(" name:",name,"\n","age:",age)
# Out:
#  name: Prachi
#  age: 25

# %%
print(" name:",name,"\t","age:",age)
# Out:
#  name: Prachi 	 age: 25

# %%
print("She said: \"Hi!\"")
# Out:
# She said: "Hi!"

# %%
print("Hello \"prachi\"")
# Out:
# Hello "prachi"

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
print('String concatenation\n', 'also\n', 'works.')
# Out:
# String concatenation
#  also
#  works.

# %%
print("3+5")
# Out:
# 3+5

# %%
print(3+6)
# Out:
# 9

# %%
print('3+5 ='

# %%
print('3+5 =',(3+5))
# Out:
# 3+5 = 8

# %%
name = input("what is your name?")
# Out:
# what is your name? vivek

# %%
print(name)
# Out:
# vivek

# %%
number = int(input("enter a number:"))
# Out:
# enter a number: 12.89
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 number = int(input("enter a number:"))
#
# ValueError: invalid literal for int() with base 10: '12.89'

# %%
type(number)
# Out:
# int

# %%
number = float(input("enter a number:"))
# Out:
# enter a number: 12.5

# %%
number
# Out:
# 12.5

# %%
type(number)
# Out:
# float

# %%
l = list(input("enter your list"))
# Out:
# enter your list 12345

# %%
l
# Out:
# ['1', '2', '3', '4', '5']
