# %%
#opening a file

# %%
open(filename,mode)

# %%
file = open("data.txt","r")

# %%
file.read()
# Out:
# 'Hello welcome to the world of analytics'

# %%
file.read()
# Out:
# ''

# %%
file.close()

# %%
file1=open("data.txt","w")

# %%
file1.write("Hello I am Prachi\n")
# Out:
# 18

# %%
file1.close()

# %%
file2 = open("data.txt","a")

# %%
file2.write("Thank you for the warm welcome")
# Out:
# 30

# %%
file2.close()

# %%
file = open("data.txt","r")

# %%
file.readline()
# Out:
# ''

# %%
file.readline()
# Out:
# 'Thank you for the warm welcome'

# %%
file.readline()
# Out:
# ''

# %%
file.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 file.readline()
#
# ValueError: I/O operation on closed file.

# %%
file.close()

# %%
file.readlines()
# Out:
# ['Hello I am Prachi\n', 'Thank you for the warm welcome']

# %%
file.read()
# Out:
# 'Hello I am Prachi\nThank you for the warm welcome'

# %%
file = open("data.txt","w")

# %%
file.write("Hello Prachi\n")
# Out:
# 13

# %%
file.write("Welcome to the world of analytics!")
# Out:
# 34

# %%
file.close()

# %%
lines = ["Hello\n","Vaibhaiv welcome\n","Akash welcome\n","Diksha welcome\n"]
file = open("data.txt","w")

# %%
file.writelines(lines)

# %%
file.close()

# %%
file = open("data.txt","w")

# %%
file.close()

# %%
file = open("data.txt","a")

# %%
file.write("Nikhil welcom]e")
# Out:
# 15

# %%
file.close()

# %%
with open("data.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# Hello
# Vaibhaiv welcome
# Akash welcome
# Diksha welcome
# Nikhil welcom]e

# %%
with open("data.txt","w") as file:
    content=file.write("Hello welcome to the world of analytics")
    print(content)
# Out:
# 39

# %%
file = open("data.txt","r")

# %%
file.tell()
# Out:
# 0

# %%
file.read()
# Out:
# 'Hello welcome to the world of analytics'

# %%
file.tell()
# Out:
# 39

# %%
file.close()

# %%
file = open("data.txt","r")

# %%
file.tell()
# Out:
# 0

# %%
file.seek(5)
# Out:
# 5

# %%
file.read()
# Out:
# ' welcome to the world of analytics'

# %%
with open("image.jpg","rb") as file:
    content=file.read()
    print(content)
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\na\x0f\x94\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x00\x01\x04\x05\x07\x06\x08\t\xff\xc4\x00e\x10\x00\x02\x01\x02\x04\x03\x05\x03\x06\x05\r\t\x0c\n\x00\x07\x00\x01\x02\x03\x11\x04\x05!1\x06\x12A\x07Qaq\xa1\x13\x81\x91\x14"2\xb1\xd1\xf0\x08\x15B\xc1\xe1\x16\x17#RUbt\x93\x94\xb2\xb3\xd2\xf1$&36Tr\x82\x92\xa2%\'457CSs\xa4\xc2\xc3\xd3DEVcdu\x83\x84\xa3\xe3Ff\x95\xe2e\x85\xf2\xff\xc4\x00\x1b\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x001\x11\x01\x01\x00\x02\x02\x03\x00\x01\x05\x00\x02\x03\x00\x01\x
# ...

# %%
with open("new_image.jpg","wb") as file:
    file.write(content)

# %%
import os

# %%
os.remove("data.txt")

# %%
os.rename("data.txt","new_data.txt")

# %%
if os.path.exists("new_data.txt"):
    print("file exists")
else:
    print("file not exists")
# Out:
# file exists

# %%
file = open("C:\Users\prach\Desktop\aa_2.0_python\loops\Whileloop.ipynb","r")
# Out:
#   Cell In[94], line 1
#     file = open("C:\Users\prach\Desktop\aa_2.0_python\loops\Whileloop.ipynb","r")
#                                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file = open(r"C:\Users\prach\Desktop\aa_2.0_python\loops\dta.txt", "r")

# %%
file.read()
# Out:
# 'Hello welcome to the world of analytics'

# %%
file.close()

# %%
file=open(r"C:\Users\prach\Web_Scrapper\data.csv","r")

# %%
file.read()
# Out:
# ',Rank,Name,Industry,Revenue (USD millions),Revenue growth,Employees,Headquarters\n0,1,Walmart,Retail,"6,11,289",6.70%,"21,00,000","Bentonville, Arkansas"\n1,2,Amazon,Retail and cloud computing,"5,13,983",9.40%,"15,40,000","Seattle, Washington"\n2,3,ExxonMobil,Petroleum industry,"4,13,680",44.80%,"62,000","Spring, Texas"\n3,4,Apple,Electronics industry,"3,94,328",7.80%,"1,64,000","Cupertino, California"\n4,5,UnitedHealth Group,Healthcare,"3,24,162",12.70%,"4,00,000","Minnetonka, Minnesota"\n5,6,CVS Health,Healthcare,"3,22,467",10.40%,"2,59,500","Woonsocket, Rhode Island"\n6,7,Berkshire Hathaway,Conglomerate,"3,02,089",9.40%,"3,83,000","Omaha, Nebraska"\n7,8,Alphabet,Technology and cloud computing,"2,82,836",9.80%,"1,56,000","Mountain View, California"\n8,9,McKesson Corporation,Health,"2,76,711",4.80%,"48,500","Irving, Texas"\n9,10,Chevron Corporation,Petroleum industry,"2,46,252",51.60%,"43,846","San Ramon, California"\n10,11,Cencora,Pharmacy wholesale,"2,38,587",11.50%,"41,500","Che
# ...

# %%
file.close()

# %%
file=open(r"C:\Users\prach\Web_Scrapper\data.csv","w")

# %%
file.write("Hello")
# Out:
# 5

# %%
file.close()
