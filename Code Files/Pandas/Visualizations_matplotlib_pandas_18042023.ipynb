# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show

# %matplotlib inline                                                              

import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore')

# %%
## variable to store the data into dataframe
viz_data = pd.read_excel("C:/Users/ajha2/OneDrive/Desktop/python-su-master/data/EXAM PERFORMANCE.xlsx")

# %%
##print the data
viz_data
# Out:
#      Gender  age Class  math score  physics score  English  chemistry score  \
# 0    female   15    XI          72             72       60               90
# 1    female   15    XI          69             90       61               88
# 2    female   15    XI          90             95       62               93
# 3      male   15    XI          47             57       53               44
# 4      male   15    XI          76             78       78               75
# ..      ...  ...   ...         ...            ...      ...              ...
# 136  female   17   XII          48             54       75               53
# 137  female   17   XII         100            100       75              100
# 138  female   17   XII          65             76       75               75
# 139    male   17   XII          72             57       78               58
# 140  female   17   XII          62             70       75               72
#
#      ROLL NO
# 0        100
# 1        101
# ...

# %%
## to check for the number of rows and columns 
viz_data.shape
# Out:
# (141, 8)

# %%
## To have an overview of the records of first 5 we use head (you can also give number inside)
viz_data.head()
# Out:
#    Gender  age Class  math score  physics score  English  chemistry score  \
# 0  female   15    XI          72             72       60               90
# 1  female   15    XI          69             90       61               88
# 2  female   15    XI          90             95       62               93
# 3    male   15    XI          47             57       53               44
# 4    male   15    XI          76             78       78               75
#
#    ROLL NO
# 0      100
# 1      101
# 2      102
# 3      103
# 4      104

# %%
## To have an overview of the records of last 5 we use head (you can also give number inside)
viz_data.tail()
# Out:
#      Gender  age Class  math score  physics score  English  chemistry score  \
# 136  female   17   XII          48             54       75               53
# 137  female   17   XII         100            100       75              100
# 138  female   17   XII          65             76       75               75
# 139    male   17   XII          72             57       78               58
# 140  female   17   XII          62             70       75               72
#
#      ROLL NO
# 136      236
# 137      237
# 138      238
# 139      239
# 140      240

# %%
## to check wether every row & column in the datasets has any null values or not
viz_data.isnull()
# Out:
#      Gender    age  Class  math score  physics score  English  \
# 0     False  False  False       False          False    False
# 1     False  False  False       False          False    False
# 2     False  False  False       False          False    False
# 3     False  False  False       False          False    False
# 4     False  False  False       False          False    False
# ..      ...    ...    ...         ...            ...      ...
# 136   False  False  False       False          False    False
# 137   False  False  False       False          False    False
# 138   False  False  False       False          False    False
# 139   False  False  False       False          False    False
# 140   False  False  False       False          False    False
#
#      chemistry score  ROLL NO
# 0              False    False
# 1              False    False
# 2              False    False
# 3              False    False
# 4              False    False
# ..               ...      ...
# ...

# %%
## to check wether every column in the datasets has any null values or not
viz_data.isnull().any()
# Out:
# Gender             False
# age                False
# Class              False
# math score         False
# physics score      False
# English            False
# chemistry score    False
# ROLL NO            False
# dtype: bool

# %%
## to check count of missing values in every column in the datasets has any null values or not
## 0 indicates none while > 0 indicates that many null values
viz_data.isnull().sum()
# Out:
# Gender             0
# age                0
# Class              0
# math score         0
# physics score      0
# English            0
# chemistry score    0
# ROLL NO            0
# dtype: int64

# %%
##type of column we are having in the datasets and their type
viz_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           141 non-null    object
#  1   age              141 non-null    int64
#  2   Class            141 non-null    object
#  3   math score       141 non-null    int64
#  4   physics score    141 non-null    int64
#  5   English          141 non-null    int64
#  6   chemistry score  141 non-null    int64
#  7   ROLL NO          141 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 8.9+ KB

# %%
## column wise statistics only for numeric column
viz_data.describe()
# Out:
#               age  math score  physics score     English  chemistry score  \
# count  141.000000  141.000000     141.000000  141.000000       141.000000
# mean    16.340426   62.822695      65.652482   72.432624        64.815603
# std      0.876925   15.821452      15.150665   12.269186        16.011872
# min     15.000000    0.000000      17.000000   32.000000        10.000000
# 25%     15.000000   53.000000      56.000000   67.000000        55.000000
# 50%     17.000000   63.000000      66.000000   75.000000        65.000000
# 75%     17.000000   73.000000      75.000000   80.000000        75.000000
# max     17.000000  100.000000     100.000000   93.000000       100.000000
#
#           ROLL NO
# count  141.000000
# mean   170.000000
# std     40.847277
# min    100.000000
# 25%    135.000000
# 50%    170.000000
# 75%    205.000000
# max    240.000000

# %%
#3 for any particular column unique data that is present
viz_data['age'].unique(),viz_data['Gender'].unique(),viz_data['Class'].unique(),viz_data['math score'].unique(),viz_data['physics score'].unique(),viz_data['English'].unique(),viz_data['chemistry score'].unique(),viz_data['ROLL NO'].unique()
# Out:
# (array([15, 16, 17], dtype=int64),
#  array(['female', 'male'], dtype=object),
#  array(['XI', 'XII'], dtype=object),
#  array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#          50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#          97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#          39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  48,  98,
#          85,  94,  84,  92, 100], dtype=int64),
#  array([ 72,  90,  95,  57,  78,  83,  43,  64,  60,  54,  52,  81,  53,
#          75,  89,  32,  42,  58,  69,  73,  71,  74,  70,  65,  87,  56,
#          61,  84,  55,  44,  41,  85,  59,  17,  39,  80,  37,  63,  51,
#          49,  26,  68,  45,  47,  86,  34,  79,  66,  67,  91,  62,  82,
#          50,  77, 100,  76], dtype=int64),
#  array([60, 61, 62, 53, 78, 90, 89, 67, 87, 43, 91, 76, 86, 93, 56, 85, 73,
#         80, 88, 77, 32, 45, 92, 54, 58, 65, 35, 55, 72, 68, 75],
#        dtype=int64),
# ...

# %%
## count of all the values for all th columns in the datasets
viz_data.count()
# Out:
# Gender             141
# age                141
# Class              141
# math score         141
# physics score      141
# English            141
# chemistry score    141
# ROLL NO            141
# dtype: int64

# %%
viz_data.value_counts()
# Out:
# Gender  age  Class  math score  physics score  English  chemistry score  ROLL NO
# female  15   XI     38          60             67       50               109        1
# male    17   XI     57          56             73       57               139        1
#         16   XI     73          74             93       72               125        1
#                     74          71             86       80               124        1
#                     78          72             87       70               113        1
#                                                                                    ..
# female  17   XII    48          56             73       51               204        1
#                                 54             75       53               236        1
#                     45          63             75       59               233        1
#                     41          51             56       48               172        1
# ...

# %%
## is there any single null value present in the dataset
pd.isnull('viz_data')
# Out:
# False

# %%
## histogram for physics score , alpha depicts transparency
viz_data['physics score'].plot.hist(color = 'r' ,orientation='vertical', cumulative=False,alpha = 0.9,bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Inference :

# %%
viz_data['math score'].plot.hist(orientation='vertical', cumulative=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
viz_data['English'].plot.hist(color = 'g',orientation='vertical', cumulative=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
viz_data['chemistry score'].plot.hist(color = 'y'orientation='vertical', cumulative=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
viz_data['chemistry score'].plot.hist(orientation='vertical', cumulative=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 ## Histogram
viz_data.plot.hist(stacked=False, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 viz_data.plot.hist(stacked=False, bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
viz_data.plot.hist(color='b', alpha=0.9, bins=50) ##aplha for changing tranparency
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
viz_data.plot.area(stacked = True)
# Out:
# <AxesSubplot:>

# %%
viz_data.plot(kind="density",x='age',y='math score')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
viz_data.plot(kind="kde",x='age',y='physics score')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
viz_data.plot(kind="pie",x='Gender',y='physics score')
# Out:
# <AxesSubplot:ylabel='physics score'>

# %%
viz_data['physics score'].plot.bar(orientation='vertical')
# Out:
# <AxesSubplot:>

# %%
## boxplot = viz_data.boxplot(by='ROLL NO')
boxplot = viz_data.boxplot(column = ['math score', 'physics score' , 'chemistry score' , 'English' ],   by=['age'])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

fig.suptitle('Adding Subtitiles', fontsize=18, fontweight='bold', style='italic')

ax = fig.add_subplot(111)

fig.subplots_adjust(top=0.85)

ax.set_title('axes title',fontsize=18, fontweight='bold', style='italic')

ax.set_xlabel('Label1')
ax.set_ylabel('Label2')

ax.text(3, 8, 'boxed italics text in data coords', style='italic',
        bbox={'facecolor':'Green', 'alpha':0.5, 'pad':10})

ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

ax.text(3, 2, u'unicode: Institut f\374r Festk\366rperphysik')

ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)


ax.plot([2], [1], 'o')
ax.annotate('peak downfall in sales figure', xy=(4,1), xytext=(6, 4),
            arrowprops=dict(facecolor='red', shrink=0.05))

ax.axis([0, 10, 0, 10])

plt.show()

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

fig, ax = plt.subplots(figsize=(8, 5))
ax.stackplot(yrs, rng + rnd, labels=['ROSA', 'EPIC', 'MEDAL'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper center')
ax.set_ylabel('Total debt')
ax.set_xlabel('Years')

ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()

# %%
x = np.random.randint(low=1, high=11, size=50)

y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,
figsize=(10, 4))

ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('X-AXIS')
ax1.set_ylabel('Y-AXIS')

ax2.hist(data, bins=np.arange(data.min(), data.max()),
label=('x', 'y'))
ax2.legend(loc=(0.65, 0.8))
ax2.set_title('Frequencies of $x$ and $y$')
ax2.yaxis.tick_right()
