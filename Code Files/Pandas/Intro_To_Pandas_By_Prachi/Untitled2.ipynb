# %%
import pandas as pd
data = pd.DataFrame({'level': ['Junior', 'Mid-level', 'Senior'],
                      'salary': [7500, 14650, 18320],
                      'position': ['Data Analyst', 'Data Scientist', 'Data Engineer']})

# %%
data.head(1)
# Out:
#     level  salary      position
# 0  Junior    7500  Data Analyst

# %%
data.tail(1)
# Out:
#     level  salary       position
# 2  Senior   18320  Data Engineer

# %%
file_path = 'database.db'  # r'C:\Users\prach\Desktop\aa_2.0_python\sql_training'

# %%
import os
if os.path.exists(file_path):
    try:
        os.remove(file_path)
        print(f"File {file_path} deleted successfully!")
    except Exception as e:
        print(f"Error deleting the file {file_path}. Details: {e}")
else:
    print(f"File {file_path} not found.")
# Out:
# Error deleting the file database.db. Details: [WinError 32] The process cannot access the file because it is being used by another process: 'database.db'

# %%
import sqlite3

cnn = sqlite3.connect('database.db')

# %%
data.to_sql('employee',cnn)
# Out:
# 3

# %%
cur = cnn.cursor()

# %%
data1= "SELECT * FROM employee"

# %%
cur.execute(data1)

cur.close()

# %%
cnn.close()

# %%
# %load_ext sql

# %%
# %sql sqlite:///database.db

# %%
# Load the extension
# %load_ext sql

# Connect to the database
# %sql sqlite:///database.db

# Run a SQL query
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT * FROM employee;
# Out:
#  * sqlite:///database.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT * FROM employee;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# ...

# %%
# %%sql
#
# SELECT * FROM employee
# Out:
#  * sqlite:///database.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nSELECT * FROM employee;\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\sql\magic.py:219, in SqlMagic.execute(self, line, cell, local_ns)
#     216     return
#     218 try:
# ...

# %%
# !pip install ipython-sql --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'San Diego', 'Dallas', 'Austin', 'Seattle', 'Denver'],
    'Date_Joined': ['2021-05-01', '2020-07-19', '2018-03-25', '2019-08-15', '2022-01-10', '2016-09-04', '2017-11-23', '2021-04-10', '2020-12-18', '2019-06-05'],
    'Salary': [50000, 60000, 75000, 85000, 90000, 95000, 110000, 120000, 130000, 140000]
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
data.to_sql('students', cnn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data.to_sql('students', cnn)
#
# AttributeError: 'dict' object has no attribute 'to_sql'

# %%
---to_datetime() - 'YYYY-MM-DD'

# %%
# Sample data
data = {
    'date_column': [
        '2021-01-01', '2022-03-15', '2020-06-30', 
        '2019-11-25', '2021-09-01', '2023-02-18',
        '2020-08-12', '2021-12-24'
    ],
    'time_column': [
        '12:30:45', '15:45:00', '08:10:20',
        '22:55:12', '06:12:45', '14:34:00',
        '03:21:50', '19:58:10'
    ]
}

# %%
from datetime import datetime, timedelta

# %%
df = pd.DataFrame(data)

# %%
df.head(8)
# Out:
#   date_column time_column
# 0  2021-01-01    12:30:45
# 1  2022-03-15    15:45:00
# 2  2020-06-30    08:10:20
# 3  2019-11-25    22:55:12
# 4  2021-09-01    06:12:45
# 5  2023-02-18    14:34:00
# 6  2020-08-12    03:21:50
# 7  2021-12-24    19:58:10

# %%
df.shape
# Out:
# (8, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  8 non-null      object
#  1   time_column  8 non-null      object
# dtypes: object(2)
# memory usage: 260.0+ bytes

# %%
df['date_column']=pd.to_datetime(df['date_column'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  8 non-null      datetime64[ns]
#  1   time_column  8 non-null      object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 260.0+ bytes

# %%
df['datetime_column'] = pd.to_datetime(df['date_column'].dt.date.astype(str) + ' ' + df['time_column'])

# %%
df.head(8)
# Out:
#   date_column time_column     datetime_column
# 0  2021-01-01    12:30:45 2021-01-01 12:30:45
# 1  2022-03-15    15:45:00 2022-03-15 15:45:00
# 2  2020-06-30    08:10:20 2020-06-30 08:10:20
# 3  2019-11-25    22:55:12 2019-11-25 22:55:12
# 4  2021-09-01    06:12:45 2021-09-01 06:12:45
# 5  2023-02-18    14:34:00 2023-02-18 14:34:00
# 6  2020-08-12    03:21:50 2020-08-12 03:21:50
# 7  2021-12-24    19:58:10 2021-12-24 19:58:10

# %%
df.info()  ---- YYYY-MM-DD HH:MM:S
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date_column      8 non-null      datetime64[ns]
#  1   time_column      8 non-null      object
#  2   datetime_column  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 324.0+ bytes

# %%
df['datetime_column']=df['datetime_column'].dt.date.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date_column      8 non-null      datetime64[ns]
#  1   time_column      8 non-null      object
#  2   datetime_column  8 non-null      object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 324.0+ bytes

# %%
df.head()
# Out:
#   date_column time_column datetime_column
# 0  2021-01-01    12:30:45      2021-01-01
# 1  2022-03-15    15:45:00      2022-03-15
# 2  2020-06-30    08:10:20      2020-06-30
# 3  2019-11-25    22:55:12      2019-11-25
# 4  2021-09-01    06:12:45      2021-09-01

# %%
df['datetime_column']=df['datetime_column'].dt.date.astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df['datetime_column']=df['datetime_column'].dt.date.astype(str)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
df['datetime_column_new'] = pd.to_datetime(df['date_column'].dt.date.astype(str) + ' ' + df['time_column'])

# %%
df.head()
# Out:
#   date_column time_column datetime_column datetime_column_new
# 0  2021-01-01    12:30:45      2021-01-01 2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15 2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30 2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25 2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01 2021-09-01 06:12:45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_column          8 non-null      datetime64[ns]
#  1   time_column          8 non-null      object
#  2   datetime_column      8 non-null      object
#  3   datetime_column_new  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 388.0+ bytes

# %%
df['datetime_column_new']=df['datetime_column_new'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_column          8 non-null      datetime64[ns]
#  1   time_column          8 non-null      object
#  2   datetime_column      8 non-null      object
#  3   datetime_column_new  8 non-null      object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 388.0+ bytes

# %%
df.head()
# Out:
#   date_column time_column datetime_column  datetime_column_new
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45

# %%
df['datetime_column_new1'] = pd.to_datetime(df['date_column'].dt.date.astype(str) + ' ' + df['time_column'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_column           8 non-null      datetime64[ns]
#  1   time_column           8 non-null      object
#  2   datetime_column       8 non-null      object
#  3   datetime_column_new   8 non-null      object
#  4   datetime_column_new1  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), object(3)
# memory usage: 452.0+ bytes

# %%
df['datetime_column_new1']=df['datetime_column_new1'].dt.year.astype(str)

# %%
df.head()
# Out:
#   date_column time_column datetime_column  datetime_column_new  \
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45
#
#   datetime_column_new1
# 0                 2021
# 1                 2022
# 2                 2020
# 3                 2019
# 4                 2021

# %%
df['YEAR']=df['date_column'].dt.year

# %%
df.head()
# Out:
#   date_column time_column datetime_column  datetime_column_new  \
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45
#
#   datetime_column_new1  YEAR
# 0                 2021  2021
# 1                 2022  2022
# 2                 2020  2020
# 3                 2019  2019
# 4                 2021  2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_column           8 non-null      datetime64[ns]
#  1   time_column           8 non-null      object
#  2   datetime_column       8 non-null      object
#  3   datetime_column_new   8 non-null      object
#  4   datetime_column_new1  8 non-null      object
#  5   YEAR                  8 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 516.0+ bytes

# %%
df['Month']=df['date_column'].dt.month

# %%
df.head()
# Out:
#   date_column time_column datetime_column  datetime_column_new  \
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45
01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date_column                8 non-null      datetime64[ns]
#  1   time_column                8 non-null      object
#  2   datetime_column            8 non-null      object
#  3   datetime_column_new        8 non-null      object
#  4   datetime_column_new1       8 non-null      object
#  5   YEAR                       8 non-null      int64
#  6   Month                      8 non-null      int64
#  7   Day                        8 non-null      int64
#  8   datetime_column_new2       8 non-null      datetime64[ns]
#  9   datetime_column_new2_date  8 non-null      object
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 772.0+ bytes

# %%
df['datetime_column_new3'] = pd.to_datetime(df['date_column'].dt.date + ' ' + df['time_column'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df['datetime_column_new3'] = pd.to_datetime(df['date_column'].dt.date + ' ' + df['time_column'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ...

# %%
df['Weekday']=df['date_column'].dt.weekday

# %%
df.head()
# Out:
#   date_column time_column datetime_column  datetime_column_new  \
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45
#
#   datetime_column_new1  YEAR  Month  Day datetime_column_new2  \
# 0                 2021  2021      1    1  2021-01-01 12:30:45
# 1                 2022  2022      3   15  2022-03-15 15:45:00
# 2                 2020  2020      6   30  2020-06-30 08:10:20
# 3                 2019  2019     11   25  2019-11-25 22:55:12
# 4                 2021  2021      9    1  2021-09-01 06:12:45
#
#   datetime_column_new2_date  Weekday
# 0                2021-01-01        4
# 1                2022-03-15        1
# 2                2020-06-30        1
# 3                2019-11-25        0
# ...

# %%
df['is_between'] = df['date_column'].between('2020-01-01','2021-01-01')

# %%
df.head(8)
# Out:
#   date_column time_column datetime_column  datetime_column_new  \
# 0  2021-01-01    12:30:45      2021-01-01  2021-01-01 12:30:45
# 1  2022-03-15    15:45:00      2022-03-15  2022-03-15 15:45:00
# 2  2020-06-30    08:10:20      2020-06-30  2020-06-30 08:10:20
# 3  2019-11-25    22:55:12      2019-11-25  2019-11-25 22:55:12
# 4  2021-09-01    06:12:45      2021-09-01  2021-09-01 06:12:45
# 5  2023-02-18    14:34:00      2023-02-18  2023-02-18 14:34:00
# 6  2020-08-12    03:21:50      2020-08-12  2020-08-12 03:21:50
# 7  2021-12-24    19:58:10      2021-12-24  2021-12-24 19:58:10
#
#   datetime_column_new1  YEAR  Month  Day datetime_column_new2  \
# 0                 2021  2021      1    1  2021-01-01 12:30:45
# 1                 2022  2022      3   15  2022-03-15 15:45:00
# 2                 2020  2020      6   30  2020-06-30 08:10:20
# 3                 2019  2019     11   25  2019-11-25 22:55:12
# 4                 2021  2021      9    1  2021-09-01 06:12:45
# ...

# %%
data = {
    'date_column': [
        '2021-01-01', '2022-03-15', '2020-06-30', 
        '2019-11-25', '2021-09-01', '2023-02-18',
        '2020-08-12', '2021-12-24'
    ],
    'time_column': [
        '12:30:45', '15:45:00', '08:10:20',
        '22:55:12', '06:12:45', '14:34:00',
        '03:21:50', '19:58:10'
    ]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   date_column time_column
# 0  2021-01-01    12:30:45
# 1  2022-03-15    15:45:00
# 2  2020-06-30    08:10:20
# 3  2019-11-25    22:55:12
# 4  2021-09-01    06:12:45
# 5  2023-02-18    14:34:00
# 6  2020-08-12    03:21:50
# 7  2021-12-24    19:58:10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  8 non-null      object
#  1   time_column  8 non-null      object
# dtypes: object(2)
# memory usage: 260.0+ bytes

# %%
df['date_column']= pd.to_datetime(df['date_column'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_column  8 non-null      datetime64[ns]
#  1   time_column  8 non-null      object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 260.0+ bytes

# %%
df['future_date']=df['date_column'] + pd.Timedelta(days=5)

# %%
df
# Out:
#   date_column time_column future_date
# 0  2021-01-01    12:30:45  2021-01-06
# 1  2022-03-15    15:45:00  2022-03-20
# 2  2020-06-30    08:10:20  2020-07-05
# 3  2019-11-25    22:55:12  2019-11-30
# 4  2021-09-01    06:12:45  2021-09-06
# 5  2023-02-18    14:34:00  2023-02-23
# 6  2020-08-12    03:21:50  2020-08-17
# 7  2021-12-24    19:58:10  2021-12-29

# %%
df['Past_date']=df['date_column'] - pd.Timedelta(days=5)

# %%
df['Past_date1']=df['date_column'] + pd.Timedelta(days=-5)

# %%
df['future_weeks']=df['date_column'] + pd.Timedelta(weeks=5)

# %%
df
# Out:
#   date_column time_column future_date  Past_date Past_date1 future_Month  \
# 0  2021-01-01    12:30:45  2021-01-06 2020-12-27 2020-12-27   2021-06-01
# 1  2022-03-15    15:45:00  2022-03-20 2022-03-10 2022-03-10   2022-08-15
# 2  2020-06-30    08:10:20  2020-07-05 2020-06-25 2020-06-25   2020-11-30
# 3  2019-11-25    22:55:12  2019-11-30 2019-11-20 2019-11-20   2020-04-25
# 4  2021-09-01    06:12:45  2021-09-06 2021-08-27 2021-08-27   2022-02-01
# 5  2023-02-18    14:34:00  2023-02-23 2023-02-13 2023-02-13   2023-07-18
# 6  2020-08-12    03:21:50  2020-08-17 2020-08-07 2020-08-07   2021-01-12
# 7  2021-12-24    19:58:10  2021-12-29 2021-12-19 2021-12-19   2022-05-24
#
#   future_Year future_weeks
# 0  2026-01-01   2021-02-05
# 1  2027-03-15   2022-04-19
# 2  2025-06-30   2020-08-04
# 3  2024-11-25   2019-12-30
# 4  2026-09-01   2021-10-06
# 5  2028-02-18   2023-03-25
# 6  2025-08-12   2020-09-16
# 7  2026-12-24   2022-01-28

# %%
df['future_Month']=df['date_column']+pd.Timedelta(Month=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df['future_Month']=df['date_column']+pd.Timedelta(Month=5)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\tslibs\timedeltas.pyx:1636, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: cannot construct a Timedelta from the passed arguments, allowed keywords are [weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds]

# %%
from pandas.tseries.offsets import DateOffset

df['future_Month'] = df['date_column'] + pd.DateOffset(months=5)

# %%
df
# Out:
#   date_column time_column future_date  Past_date Past_date1 future_Month
# 0  2021-01-01    12:30:45  2021-01-06 2020-12-27 2020-12-27   2021-06-01
# 1  2022-03-15    15:45:00  2022-03-20 2022-03-10 2022-03-10   2022-08-15
# 2  2020-06-30    08:10:20  2020-07-05 2020-06-25 2020-06-25   2020-11-30
# 3  2019-11-25    22:55:12  2019-11-30 2019-11-20 2019-11-20   2020-04-25
# 4  2021-09-01    06:12:45  2021-09-06 2021-08-27 2021-08-27   2022-02-01
# 5  2023-02-18    14:34:00  2023-02-23 2023-02-13 2023-02-13   2023-07-18
# 6  2020-08-12    03:21:50  2020-08-17 2020-08-07 2020-08-07   2021-01-12
# 7  2021-12-24    19:58:10  2021-12-29 2021-12-19 2021-12-19   2022-05-24

# %%
df['future_Year'] = df['date_column'] + pd.DateOffset(years=5)

# %%
df
# Out:
#   date_column time_column future_date  Past_date Past_date1 future_Month  \
# 0  2021-01-01    12:30:45  2021-01-06 2020-12-27 2020-12-27   2021-06-01
# 1  2022-03-15    15:45:00  2022-03-20 2022-03-10 2022-03-10   2022-08-15
# 2  2020-06-30    08:10:20  2020-07-05 2020-06-25 2020-06-25   2020-11-30
# 3  2019-11-25    22:55:12  2019-11-30 2019-11-20 2019-11-20   2020-04-25
# 4  2021-09-01    06:12:45  2021-09-06 2021-08-27 2021-08-27   2022-02-01
# 5  2023-02-18    14:34:00  2023-02-23 2023-02-13 2023-02-13   2023-07-18
# 6  2020-08-12    03:21:50  2020-08-17 2020-08-07 2020-08-07   2021-01-12
# 7  2021-12-24    19:58:10  2021-12-29 2021-12-19 2021-12-19   2022-05-24
#
#   future_Year
# 0  2026-01-01
# 1  2027-03-15
# 2  2025-06-30
# 3  2024-11-25
# 4  2026-09-01
# 5  2028-02-18
# 6  2025-08-12
# 7  2026-12-24

# %%
# 4. Formatting datetime to string
df['formatted_date'] = df['date_column'].dt.strftime('%Y-%m-%d')

# %%
df
# Out:
#   date_column time_column future_date  Past_date Past_date1 future_Month  \
# 0  2021-01-01    12:30:45  2021-01-06 2020-12-27 2020-12-27   2021-06-01
# 1  2022-03-15    15:45:00  2022-03-20 2022-03-10 2022-03-10   2022-08-15
# 2  2020-06-30    08:10:20  2020-07-05 2020-06-25 2020-06-25   2020-11-30
# 3  2019-11-25    22:55:12  2019-11-30 2019-11-20 2019-11-20   2020-04-25
# 4  2021-09-01    06:12:45  2021-09-06 2021-08-27 2021-08-27   2022-02-01
# 5  2023-02-18    14:34:00  2023-02-23 2023-02-13 2023-02-13   2023-07-18
