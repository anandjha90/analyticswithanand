# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample text data
text = """
I love the new smartphone! The camera quality is amazing, and the battery life is excellent. Highly recommended!
The laptop is great for work but a bit heavy. The screen resolution is fantastic, and it has a long battery life.
I’m very satisfied with the tablet. The display is clear and vibrant, and the overall performance is smooth.
The smartwatch has a sleek design and many useful features. However, the battery life could be improved.
I bought the new headphones, and they sound incredible. The noise-cancellation is effective, but they are a bit pricey.
"""

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data: stock prices over time
data = {
    'Date': ['2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04', '2024-08-05'],
    'StockPrice': [150.75, 152.30, 155.00, 153.25, 157.80]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the stock price trend
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['StockPrice'], marker='o', linestyle='-', color='b')

# Adding titles and labels
plt.title('Stock Price Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')
plt.grid(True)

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to fit labels
plt.show()

# %%
customer_data = {
    'CustomerID': [1, 2, 3, 4],
    'Latitude': [40.7128, 34.0522, 41.8781, 37.7749],
    'Longitude': [-74.0060, -118.2437, -87.6298, -122.4194],
    'Details': ['Customer A', 'Customer B', 'Customer C', 'Customer D']
}

store_data = {
    'StoreID': [101, 102, 103],
    'Latitude': [40.7306, 34.0522, 37.7749],
    'Longitude': [-73.9352, -118.2437, -122.4194],
    'PromotionalOffer': ['10% off on electronics', 'Buy 1 Get 1 Free', '20% off on all items']
}

# %%
pip install folium pandas

# %%
pip install ipython
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...

# %%
import folium
import pandas as pd

# Create DataFrames from the sample data
customer_df = pd.DataFrame({
    'CustomerID': [1, 2, 3, 4],
    'Latitude': [40.7128, 34.0522, 41.8781, 37.7749],
    'Longitude': [-74.0060, -118.2437, -87.6298, -122.4194],
    'Details': ['Customer A', 'Customer B', 'Customer C', 'Customer D']
})

store_df = pd.DataFrame({
    'StoreID': [101, 102, 103],
    'Latitude': [40.7306, 34.0522, 37.7749],
    'Longitude': [-73.9352, -118.2437, -122.4194],
    'PromotionalOffer': ['10% off on electronics', 'Buy 1 Get 1 Free', '20% off on all items']
})

# Create a map centered around the average location
map_center = [customer_df['Latitude'].mean(), customer_df['Longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=5)

# Add customer locations to the map
for _, row in customer_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Details'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mymap)

# Add store locations to the map with promotional offers
for _, row in store_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Store {row['StoreID']} - {row['PromotionalOffer']}",
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(mymap)

# Save the map to an HTML file
mymap.save('customer_store_map.html')

# %%
from IPython.display import IFrame

# Display the HTML file
IFrame('customer_store_map.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="customer_store_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import webbrowser

# Open the HTML file in the default web browser
webbrowser.open('customer_store_map.html')
# Out:
# False

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data: sales volumes across different product categories
data = {
    'ProductCategory': ['Electronics', 'Furniture', 'Clothing', 'Books', 'Toys'],
    'SalesVolume': [1200, 800, 1500, 500, 300]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting the sales volumes by product category
plt.figure(figsize=(10, 6))
plt.bar(df['ProductCategory'], df['SalesVolume'], color='green')

# Adding titles and labels
plt.title('Sales Volumes Across Different Product Categories')
plt.xlabel('Product Category')
plt.ylabel('Sales Volume')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate sample data
data = {
    'Area1': [5, 3, 0, 2, 4],
    'Area2': [2, 4, 5, 6, 1],
    'Area3': [0, 1, 4, 7, 2],
    'Area4': [1, 3, 6, 8, 5],
    'Area5': [2, 5, 8, 7, 6]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Generate a heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(df, annot=True, cmap="YlGnBu", cbar=True, linewidths=.5)

# Adding titles and labels
plt.title('Heatmap Showing Areas of Website Where Users Spend Most Time')
plt.xlabel('Website Areas')
plt.ylabel('Time (in minutes)')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data: metrics for two product versions
data = {
    'Metric': ['Conversion Rate', 'Average Order Value', 'Click-Through Rate'],
    'Version A': [0.12, 75.0, 0.05],
    'Version B': [0.15, 80.0, 0.06]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the metric column as the index
df.set_index('Metric', inplace=True)

# Plotting the metrics comparison
df.plot(kind='bar', figsize=(10, 6), color=['blue', 'green'])

# Adding titles and labels
plt.title('A/B Test Results: Comparison of Key Metrics Between Two Product Versions')
plt.xlabel('Metric')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.legend(title='Product Version')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Sample JSON data
data = [
    {
        "location": {
            "city": "New York",
            "state": "NY",
            "country": "USA"
        },
        "weather": {
            "temperature": 75,
            "conditions": "Sunny",
            "humidity": 60
        },
        "timestamp": "2024-08-17T12:00:00Z"
    },
    {
        "location": {
            "city": "San Francisco",
            "state": "CA",
            "country": "USA"
        },
        "weather": {
            "temperature": 68,
            "conditions": "Foggy",
            "humidity": 75
        },
        "timestamp": "2024-08-17T12:00:00Z"
    },
    {
        "location": {
            "city": "Chicago",
            "state": "IL",
            "country": "USA"
        },
        "weather": {
            "temperature": 72,
            "conditions": "Partly Cloudy",
            "humidity": 50
        },
        "timestamp": "2024-08-17T12:00:00Z"
    }
]

# Convert JSON data to DataFrame
df = pd.json_normalize(data, sep='_')

# Display the DataFrame
print(df)

# Example analysis: Average temperature
average_temperature = df['weather_temperature'].mean()
print(f'Average Temperature: {average_temperature}°F')
# Out:
#               timestamp  location_city location_state location_country  \
# 0  2024-08-17T12:00:00Z       New York             NY              USA
# 1  2024-08-17T12:00:00Z  San Francisco             CA              USA
# 2  2024-08-17T12:00:00Z        Chicago             IL              USA
#
#    weather_temperature weather_conditions  weather_humidity
# 0                   75              Sunny                60
# 1                   68              Foggy                75
# 2                   72      Partly Cloudy                50
# Average Temperature: 71.66666666666667°F
